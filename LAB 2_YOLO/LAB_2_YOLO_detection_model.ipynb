# %% [markdown]
# #LAB 2: YOLO detection model

# %% [markdown]
# <h4><div style="text-align: right"> Due date: 15:00 Oct 28, 2024.  </div> <br>
# <div style="text-align: right"> Please upload your file and final-report at PLATO before the class in the form of [ID_Name_Lab1.ipynb]. </div></h4>

# %% [markdown]
# ### *Instructions:*
# - Write a program implementing a particular algorithm to solve a given problem.
# - <span style="color:red">**Report and discuss your results. Analyze the algorithm, theoretically and empirically.**</span>
# - You must write their own answers and codes (<span style="color:red">**if not you will get a F grade**</span>).

# %% [markdown]
# <h2><span style="color:blue">[202055546] [박지용]</span> </h2>

# %%
import datetime
print("This code is written at " + str(datetime.datetime.now()))
# Out:
# This code is written at 2024-11-01 18:24:11.227624

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.26.4)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import torch.utils.data as data
from torch.autograd import Variable

import torchvision.datasets as dsets

import numpy as np
import cv2

import os
import struct
import copy
import random

import time
import datetime

import math

from PIL import Image
import torchvision.transforms as transforms
from torchvision.transforms import Compose, ToTensor, Resize
from torch.utils import data
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1. What is the Object Detection?
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1pOo5As8Qo8bQOQjOkkpRwjVKcKNB4gSE" alt="no_image" style="width: 800px;"/>
# >
# > - The difference between $\bf{classification}$ (left) and $\bf{detection}$ (right) is simple
# >
# > - In image classification, the entire image is classified with a single label
# >
# > - In object detection, the network localizes (potentially multiple) objects within the image
# >
# > - Therefore, given the image, the obejct detection networks ouput a list of bounding box, class label, and **probability/confidence score**
# >
#
# ### 2. About YOLO (Main idea)
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1K7tvcGXdRHBc_t5p-m3uyRrCBFbJ9ze5" alt="no_image" style="width: 800px;"/>
# >
# > - YOLO is an algorithm for object detection
# >
# > - They reframe object detection as a $\bf{single\ regression\ problem}$, straight from image pixels to bounding box coordinates and class probabilities
# >
# > - Using YOLO, you only look once (YOLO) at an image to predict what objects are present and where they are
# >
# > - The advantage of YOLO is the speed, which is extremely fast, since the authors reframe detection as a regression problem not using a complex pipeline
# >
# > - What are differences between YOLO and previous detectors?? Refer to https://towardsdatascience.com/r-cnn-fast-r-cnn-faster-r-cnn-yolo-object-detection-algorithms-36d53571365e

# %% [markdown]
# ### 3. Building a YOLO with PyTorch
#
# > ### YOLO model:
# > - 22Convolutional Layers
# >
# >     - Note that, first and 20th conv layers have stride 2 for halving output size
# >
# > - 4 Max Pooling Layers
# >
# > - 2 Fully Connected Layers
# >
# > - Leaky ReLu Activation for all layers except for the last layer
#
# ### 4. Implementing YOLO
# >
# > - The input image is divided into an S $\times$ S grid of cells
# >
# > - Each grid cell predicts B (=2) bounding boxes as well as C (=20) class probabilities
# >
# > - Each bounding box consists of 5 predictions: x, y, w, h, and confidence
# >
# > - The (x,y) coordinates represent the center of the box relative to the bounds of the grid cell
# >
# > - The width and height are predicted relative to the whole image
# >
# > - If no object exists in that cell, the confidence score is zero.
# >
# > - If the cell contains objects, the confidence score is equal to the intersection over union (IOU) between the predicted box and the ground truth (**This is important for building the loss function**)
# >
# > - Thus, the output vector is a S $\times$ S $\times$ (B $\times$ 5 + C) (= 7 $\times$ 7 $\times$ 30)
# >
# > <img src="https://drive.google.com/uc?export=view&id=1LdKtTyYjGKKWmu-4nTYBEMI7n4Sk0aeB" alt="no_image" style="width: 600px;"/>
# >
# > - You must study *generate_target* function in detail, it contains the process of generating output vectors
# >
# > Step 1: Load the dataset
# >
# > Step 2: Build the YOLO network ($\bf{4 points}$)
# >>
# >>  <img src="https://drive.google.com/uc?export=view&id=1c4yOWTZacei0_pFoI47wfxVEhM5Tms8X" alt="no_image" style="width: 800px;"/>
# >>
# >> - Following the YOLO model, you build yolo network
# >> - **Note that our model is different from network of original paper. Please follow above figure.**
# >> - You must fill out the blank in **self.pre_train_net** and **self.post_net** blocks
# >> - All layers use the following Leaky ReLU (0.1 slope for negative part (default=0.01))
# >>
# >>
# >> #### **self.pre_train_net**
# >>
# >>
# >>
# >>| Name       | Filters              | Output Dimension | Padding |
# >>|------------|----------------------|------------------| ------- |
# >>| Conv 1     | 7 x 7 x 64, stride=2 | 224 x 224 x 64   | 3       |
# >>| LeakyReLU  | negative_slop=0.1   | 224 x 224 x 64   |         |
# >>| Max Pool 1 | 2 x 2, stride=2      | 112 x 112 x 64   |         |
# >>|
# >>| Conv 2     | 3 x 3 x 192          | 112 x 112 x 192  | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 112 x 112 x 192  |         |
# >>| Max Pool 2 | 2 x 2, stride=2      | 56 x 56 x 192    |         |
# >>|
# >>| Conv 3     | 1 x 1 x 128          | 56 x 56 x 128    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 128    |         |
# >>| Conv 4     | 3 x 3 x 256          | 56 x 56 x 256    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 256    |         |
# >>| Conv 5     | 1 x 1 x 256          | 56 x 56 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 256    |         |
# >>| Conv 6     | 3 x 3 x 512          | 56 x 56 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 512    |         |
# >>| Max Pool 3 | 2 x 2, stride=2      | 28 x 28 x 512    |         |
# >>|
# >>| Conv 7     | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 8     | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 9     | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 10    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 11    | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 12    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 13    | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 14    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 15    | 1 x 1 x 512          | 28 x 28 x 512    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 16    | 3 x 3 x 1024         | 28 x 28 x 1024   | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 1024   |         |
# >>| Max Pool 4 | 2 x 2, stride=2      | 14 x 14 x 1024   |         |
# >>|
# >>| Conv 17    | 1 x 1 x 512          | 14 x 14 x 512    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 14 x 14 x 512    |         |
# >>| Conv 18    | 3 x 3 x 1024         | 14 x 14 x 1024   | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 14 x 14 x 1024   |         |
# >>
# >> #### **self.post_net**
# >>
# >>| Name      | Filters                | Output Dimension | Padding |
# >>|-----------|------------------------|------------------| ------- |
# >>| Conv 19   | 3 x 3 x 1024           | 14 x 14 x 1024   | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 14 x 14 x 1024   |         |
# >>| Conv 20   | 3 x 3 x 1024, stride=2 | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 7 x 7 x 1024     |         |
# >>| Conv 21   | 3 x 3 x 1024           | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 7 x 7 x 1024     |         |
# >>| Conv 22   | 3 x 3 x 1024           | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 7 x 7 x 1024     |         |
# >>
# > Step 3: Loss function ($\bf{6 points}$)
# >
# >> - Fill out the code considering the loss function in YOLO
# >> - The loss function is composed like below
# >> <img src="https://drive.google.com/uc?export=view&id=1QcAP__J50M379GAul7SlhAzzU551tuDj" alt="no_image" style="width: 600px;"/>
# >>
# >> - $\mathbb{1}_{obj}$ is defined as follows:
# >>    - 1, if an object is present in grid cell $i$ and the $j$th bounding box predictor
# >>    - 0, otherwise
# >>
# >> - YOLO predicts multiple bounding boxes per grid cell (in our case, 2 bounding boxes are predicted)
# >> - In train stage, YOLO requires one bounding box predictor to be responsible for each object
# >> - The code assigns one predictor to be "responsible" for predicting an object where the predictor has the highest IOU with the ground truth
# >> - The loss function is divided into the three sub-sections
# >>    1. Classification ( $\bf{6}$ classes ) ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=13mnxg_GNtbWnYLpe1P6zopf693zTYe22" alt="no_image" style="width: 300px;"/>
# >>
# >>       - Similar to sum-squared error for classification except for $\mathbb{1}_{obj}$ term
# >>
# >>       - Note that, we do not penalize classification error when no object is present on the cell (by $\mathbb{1}_{obj}$ term)
# >>
# >>    2. No object appears in cell ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=1R74HzbRLoX2K5zun8XSLAnRQlKq25XFV" alt="no_image" style="width: 300px;"/>
# >>
# >>       - Compute the loss associated with the confidence score for each bounding box predictor
# >>
# >>       - $\mathbb{1}_{noobj}$ is equal to one when there is no object in the cell, and 0 other wise
# >>    3. Bounding box coordinates (x,y,h,w) regression (4 scalars), and Object confidence ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=1lXs5lHUiXGxgMRNCiViY6SyRDL52gQsy" alt="no_image" style="width: 600px;"/>
# >>
# >>       - Compute the loss realted to the predicted bounding box position $(x,y)$ and width/height $(w,h)$
# >>
# >>       - Note that width/height are adapted square root before computing the loss
# >>
# >>       - In order to solve the problem that small deviations in large boxes matter less than in small boxes
# >>
# >>       - Compute the loss associated with the confidence score for the cell which is responsible for the object
# >>
# >> - Following the paper, $\lambda_{coord} = 5$ and $\lambda_{noobj} = 0.5$
# >>
# > Step 4: Train Model ($\bf{2 points}$)
# >>
# >> - Based on the above code, you build train code on your own
# >> - The necessary things are provided (e.g., *optimizer* and *num_epoch*)
# >> - Note that, we offer the pre-trained model (0.685 mAP) since it requires large training time.
# >> - If you construct your code correctly, the performance of mAP will be over 0.7 mAP in 10 epochs (about 15 minitues.)
# >>
# > Step 5: Inference
# >>
# >> - We offer the test code in below
# >> - You can check the qualitative results using the visualization code
# >> - The quantitative results will be evaluated by using the mAP code
# >> - If the performance of mAP is significantly decreased from the pre-trained model (0.685 mAP), your code will be wrong
# >>
# >> Step 5-1: Inference (Visualization)
# >>
# >> Step 5-2: Inference (mAP)

# %% [markdown]
# ### Step 1. Load the dataset

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "7"

class YoloDataset(data.Dataset):
    def __init__(self, root, list_file, train, transform=None):
        self.image_size = 448
        self.root = root
        self.train = train
        self.transform = transform
        self.fnames = []
        self.boxes = []
        self.labels = []
        self.color_jitter = Compose([transforms.ColorJitter(brightness=0.1,contrast=0.1, saturation=0.1, hue=0.1),
                                                 transforms.ToTensor()])
        self.plain = Compose([transforms.ToTensor()])
        self.resize = Compose([transforms.ToPILImage(),
                              transforms.Resize((self.image_size, self.image_size)),
                              transforms.ToTensor()])

        with open(list_file) as f:
            lines = f.readlines()

        for line in lines:
            splited = line.strip().split()
            self.fnames.append(splited[0])
            num_boxes = (len(splited) - 1) // 5
            box = []
            label = []
            for i in range(num_boxes):
                x_min = float(splited[1+5*i])
                y_min = float(splited[2+5*i])
                x_max = float(splited[3+5*i])
                y_max = float(splited[4+5*i])
                c = splited[5+5*i]
                box.append([x_min, y_min, x_max, y_max])
                label.append(int(c)+1)
            self.boxes.append(torch.Tensor(box))
            self.labels.append(torch.LongTensor(label))
        self.num_samples = len(self.boxes)

    def img_pre_process(self, img, boxes, labels):

        if random.random() < 0.5:
            im_lr = np.fliplr(img).copy()
            height, width, c = img.shape
            x_min = width - boxes[:, 2]
            x_max = width - boxes[:, 0]
            boxes[:,0] = x_min
            boxes[:,2] = x_max
            img = im_lr

        ## Converting the image and box information scaling
        if random.random() < 0.5:
            scale = random.uniform(0.8, 1.2)
            height, width, c = img.shape
            img = cv2.resize(img, (int(width * scale), height))
            boxes = boxes * torch.FloatTensor([[scale, 1, scale, 1]]).expand_as(boxes)

        ## Image translation
        if random.random() < 0.5:
            center = (boxes[:,2:] + boxes[:,:2]) / 2
            height, width, c = img.shape
            shifted_img = np.zeros((height, width, c), dtype=img.dtype)

            w_range = int(random.uniform(-width*0.2, width*0.2))
            h_range = int(random.uniform(-height*0.2, height*0.2))

            if w_range<0 and h_range<0:
                shifted_img[:height+h_range,:width+w_range,:] = img[-h_range:,-w_range:,:]

            elif w_range<0 and h_range>=0:
                shifted_img[h_range:,:width+w_range,:] = img[:height-h_range,-w_range:,:]

            elif w_range>=0 and h_range>=0:
                shifted_img[h_range:,w_range:,:] = img[:height-h_range,:width-w_range,:]

            elif w_range>=0 and h_range<0:
                shifted_img[:height+h_range,w_range:,:] = img[-h_range:,:width-w_range,:]

            wh_range = torch.FloatTensor([[w_range, h_range]]).expand_as(center)
            center = center + wh_range

            mask1 = (center[:,0] > 0) & (center[:,0] < width)
            mask2 = (center[:,1] > 0) & (center[:,1] < height)
            mask = (mask1 & mask2).view(-1,1)

            boxes_in = boxes[mask.expand_as(boxes)].view(-1,4)

            if len(boxes_in) != 0:
                box_shift = torch.FloatTensor([[w_range, h_range, w_range, h_range]]).expand_as(boxes_in)
                boxes_in = boxes_in + box_shift

                labels_in = labels[mask.view(-1)]
                labels = labels_in
                img = shifted_img
                boxes = boxes_in

        ## Image cropping
        if random.random() < 0.5:
            center = (boxes[:,2:] + boxes[:,:2]) / 2
            height, width, c = img.shape
            h = int(random.uniform(0.6*height,height))
            w = int(random.uniform(0.6*width,width))
            x = int(random.uniform(0,width-w))
            y = int(random.uniform(0,height-h))

            center = center - torch.FloatTensor([[x, y]]).expand_as(center)
            mask1 = (center[:,0]>0) & (center[:,0]<w)
            mask2 = (center[:,1]>0) & (center[:,1]<h)
            mask = (mask1 & mask2).view(-1, 1)

            boxes_in = boxes[mask.expand_as(boxes)].view(-1,4)

            if (len(boxes_in)!=0):
                box_shift = torch.FloatTensor([x,y,x,y]).expand_as(boxes_in)

                boxes_in = boxes_in - box_shift
                boxes_in[:,0]=boxes_in[:,0].clamp_(min=0,max=w)
                boxes_in[:,2]=boxes_in[:,2].clamp_(min=0,max=w)
                boxes_in[:,1]=boxes_in[:,1].clamp_(min=0,max=h)
                boxes_in[:,3]=boxes_in[:,3].clamp_(min=0,max=h)

                labels = labels[mask.view(-1)]
                img_cropped = img[y:y+h, x:x+w, :]
                boxes = boxes_in
                img = img_cropped

        return img, boxes, labels

# %%
    def generate_target(self, img, boxes, labels):


        grid_size = 7
        h,w,_ = img.shape
        boxes /= torch.Tensor([w,h,w,h]).expand_as(boxes) # Normalize the bounding box coordinates (0 to 1) by dividing by image width and height
        target = torch.zeros((grid_size, grid_size, 30)) #0으로 구성된 7x7x30/ 0으로 초기화 되어 있고 필요한 부분만 채우겠다
        cell_size = 1./grid_size # Define the size of each grid cell in the normalized image space.

        wh = boxes[:,2:] - boxes[:,:2] # Calculate width and height of each bounding box.
        cxcy = (boxes[:,2:] + boxes[:,:2]) / 2 # Calculate center coordinates (cx,cy) of each bounding box.

        for i in range(cxcy.size()[0]): #Iterate over each bounding box in the image.
            cxcy_sample = cxcy[i] # center pixel  Extract the center (cx,cy) of the current bounding box
            ij = (cxcy_sample/cell_size).ceil()-1 #Determine which grid cell (i,j) the center (cx,cy) falls into.
            target[int(ij[1]),int(ij[0]),4] = 1
            target[int(ij[1]),int(ij[0]),9] = 1
            target[int(ij[1]),int(ij[0]),int(labels[i])+9] = 1  # 만약 9번째 값이 정답이라면,9번째 인덱스에 1 할당/ 정답인 인덱스에 1을 할당

            xy = ij*cell_size # Calculate the top-left corner of the grid cell.
            delta_xy = (cxcy_sample -xy)/cell_size # Converting delta_xy to the size
                                                   # relative to the bounds of the grid cell
            target[int(ij[1]),int(ij[0]),2:4] = wh[i]
            target[int(ij[1]),int(ij[0]),:2] = delta_xy
            target[int(ij[1]),int(ij[0]),7:9] = wh[i]
            target[int(ij[1]),int(ij[0]),5:7] = delta_xy

        return target

    def RandomBrightness(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])


            v = v*adjust
            v = np.clip(v, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr
    def RandomSaturation(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            s = s*adjust
            s = np.clip(s, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr
    def RandomHue(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            h = h*adjust
            h = np.clip(h, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr

    def randomBlur(self,bgr):
        if random.random()<0.5:
            bgr = cv2.blur(bgr,(5,5))
        return bgr

    def __getitem__(self, idx):
        fname = self.fnames[idx]
        img = cv2.imread(os.path.join(self.root+fname)) #img : 원본영상
        boxes = self.boxes[idx].clone()
        labels = self.labels[idx].clone()

        if self.train:
            img = self.randomBlur(img)
            img = self.RandomBrightness(img)
            img = self.RandomHue(img)
            img = self.RandomSaturation(img)                #영상의 rgb 값들 변화 ex) 블러추가, 밝기변화
            img, boxes, labels = self.img_pre_process(img, boxes, labels)# label은변화하지 않지만 box는 변화 8개정도의 augmentation 통과

        target = self.generate_target(img, boxes, labels) # 7x7x30

        # Image processing
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        img = self.plain(img)
        img = self.resize(img)
        img = 2 * img - 1

        return img, target

    def __len__(self):
        return self.num_samples

# %% [markdown]
# ### Step 2. Build the YOLO network (2 points)

# %% [markdown]
# > You should build model using nn.Sequential. Otherwise, problem arises when loading pretrained weights.

# %%
class YOLO(nn.Module):
    def __init__(self):
        super(YOLO, self).__init__()
        #[채널,kernelsize,padding,stride]
        pre_train = [[64,7,3,2],'MP', [192,3,1,1],'MP', [128,1,0,1], [256,3,1,1], [256,1,0,1], [512,3,1,1],'MP',[256,1,0,1],[512,3,1,1],[256,1,0,1],[512,3,1,1],[256,1,0,1], [512,3,1,1],[256,1,0,1],[512,3,1,1], [512,1,0,1],[1024,3,1,1],'MP',[512,1,0,1],[1024,3,1,1]]
        post_net = [[1024,1],[1024,2],[1024,1],[1024,1]]

        self.pre_train_net = self._make_pre_train_layers(pre_train)
        self.post_net = self._make_post_net_layers(post_net)

        self.FC1 = nn.Sequential(
            nn.Linear(50176, 4096),
            nn.LeakyReLU(),
            nn.Dropout()
        )

        self.FC2 = nn.Sequential(
            nn.Linear(4096, 1470)
        )

        self.pre_train_net.cuda()
        self.post_net.cuda()
        self.FC1.cuda()
        self.FC2.cuda()

        self._initialize_weights()

    def forward(self, x):
        output = self.pre_train_net(x)
        output = self.post_net(output)

        # Ready to going for FC layer
        output = output.view(output.size(0), -1)

        output = self.FC1(output)
        output = self.FC2(output)

        output = output.view(output.size(0), 7, 7, 30)
        # Converting the output shape to the (batch_size, 7, 7, 30)
        output = F.relu(output)

        return output

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()

    def _make_pre_train_layers(self,pre_train):
        layers = []
        input_ch =3

        for x in pre_train:
          if x == 'MP':
            layers.append(nn.MaxPool2d(kernel_size=2, stride=2))


          else:
            layers.append(nn.Conv2d(input_ch, x[0], kernel_size=x[1],padding=x[2],stride = x[3]))
            layers.append(nn.LeakyReLU(negative_slope=0.1))
            input_ch = x[0]


        return nn.Sequential(*layers)


    def _make_post_net_layers(self,post_net):
        layers = []
        input_ch =1024

        for x in post_net:

          layers.append(nn.Conv2d(input_ch,x[0], kernel_size=3, padding=1,stride = x[1]))
          layers.append(nn.LeakyReLU(negative_slope=0.1))
          input_ch = x[0]

        return nn.Sequential(*layers)

# %% [markdown]
# ### Step 3. Loss function (6 points)

# %%
class yoloLoss(nn.Module):
    def __init__(self,l_coord,l_noobj):
        super(yoloLoss,self).__init__()
        self.l_coord = l_coord
        self.l_noobj = l_noobj

    def compute_prob_error(self, pred, target): ## classification error
        contain = target[:,:,:,4] > 0 # [Batch_size, 7, 7, 1]
        contain = contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]
        prob_loss = F.mse_loss(pred[contain].view(-1, 30)[:,10:], target[contain].view(-1, 30)[:,10:], size_average=False)
        return prob_loss

    def not_contain_obj_error(self, pred, target): ## Error where no object appears in cell
        not_contain = target[:,:,:,4] == 0 # [Batch_size, 7, 7, 1]
        not_contain = not_contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]
        noobj_loss1 = F.mse_loss(pred[not_contain].view(-1,30)[:,4] , target[not_contain].view(-1,30)[:,4] , size_average=False)

        return noobj_loss1


    def contain_obj_error(self, pred, target): ##
        contain = target[:,:,:,4] > 0 # [Batch_size, 7, 7, 1]
        contain = contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]

        contain_pred = pred[contain].contiguous().view(-1,30) # Only cell which contains the object are remained
        box_pred = contain_pred[:,:10].contiguous().view(-1,5) # Reshaping

        contain_target = target[contain].contiguous().view(-1,30)
        box_target = contain_target[:,:10].contiguous().view(-1,5)

        # Note that, We assign one predictor to be "responsible" for predicting
        # an object based on which prediction has the highest current IOU with the ground truth
        # Then, other prediction is "not responsible" for predicting an object
        # That component is included in "contain_noobj_mask variables

        contain_obj_mask = torch.cuda.ByteTensor(box_target.size()).zero_() # Create the mask
        contain_noobj_mask = torch.cuda.ByteTensor(box_target.size()).zero_()

        target_iou_gt = torch.zeros(box_target[:,0].size()).cuda() # In order to save the IoU for confidence
                                                                   # of the cell which contains object

        for i in range(0, box_target.size()[0], 2):
            box_p = box_pred[i:i+2] # For 2 bounding boxes information
            box_p_coord = Variable(torch.FloatTensor(box_p.size())) # Box coordinate (x_min, y_min, x_max, y_max)
            box_p_coord[:,:2] = box_p[:,:2] - 0.5 * box_p[:,2:4]
            box_p_coord[:,2:4] = box_p[:,:2] + 0.5 * box_p[:,2:4]

            box_t = box_target[i].contiguous().view(-1,5)
            box_t_coord = Variable(torch.FloatTensor(box_t.size()))
            box_t_coord[:,:2] = box_t[:,:2] - 0.5 * box_t[:,2:4]
            box_t_coord[:,2:4] = box_t[:,:2] + 0.5 * box_t[:,2:4]

            iou = self.compute_iou(box_p_coord[:,:4], box_t_coord[:,:4]) # [2,]
                                                      # compute IoU between prediction and target boxes,

            gt_iou, max_idx = iou.max(0)
            contain_obj_mask[i+max_idx] = 1
            contain_noobj_mask[i+1-max_idx] = 1

            target_iou_gt[i+max_idx] = gt_iou.data.cuda()

        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        target_iou_gt = target_iou_gt.to(device)

        ## For the cell which contains object
        contain_box_pred = box_pred[contain_obj_mask].view(-1,5)

        ## For the cell which does not contain object
        not_contain_box_pred = box_pred[contain_noobj_mask].view(-1,5)

        ## For target domain
        contain_box_target = box_target[contain_obj_mask].view(-1,5)
        not_contain_box_target = box_target[contain_obj_mask].view(-1,5)
        not_contain_box_target[:,4] = 0

        ## For the GT IoU
        contain_iou_target = target_iou_gt.view(-1,1)

        obj_loss = F.mse_loss(contain_box_pred[:,4], contain_iou_target, size_average=False)
        xy_loss = F.mse_loss(contain_box_pred[:,:2], contain_box_target[:,:2], size_average=False)
        wh_loss = F.mse_loss(torch.sqrt(contain_box_pred[:,2:4]), torch.sqrt(contain_box_target[:,2:4]), size_average=False)
        noobj_loss2 = F.mse_loss(not_contain_box_pred[:,4], not_contain_box_target[:,4], size_average=False)

        return obj_loss, xy_loss, wh_loss, noobj_loss2

    def compute_iou(self, box_p, box_t):

        pred_area = (box_p[:,2] - box_p[:,0]) * (box_p[:,3] - box_p[:,1]) # [2,]
        target_area = (box_t[:,2] - box_t[:,0]) * (box_t[:,3] - box_t[:,1]) #[1,]

        box_p = box_p.unsqueeze(1).expand(2,1,4)
        box_t = box_t.unsqueeze(0).expand(2,1,4)

        inter_lt = torch.max(box_p[:,:,:2], box_t[:,:,:2]) # [2,1,2]

        inter_rb = torch.min(box_p[:,:,2:], box_t[:,:,2:]) # [2,1,2]

        wh = inter_rb - inter_lt # [2,1,2]
        wh[wh<0] = 0

        inter_area = wh[:,:,0] * wh[:,:,1] # [2,1]
        pred_area = pred_area.unsqueeze(1).expand_as(inter_area)
        target_area = target_area.unsqueeze(0).expand_as(inter_area)

        iou = inter_area / (pred_area + target_area - inter_area)

        return iou



    def forward(self,pred,target):

        batch_size = pred.size()[0]

        noobj_loss1 = self.not_contain_obj_error(pred, target)
        prob_loss = self.compute_prob_error(pred, target)
        obj_loss, xy_loss, wh_loss, noobj_loss2 = self.contain_obj_error(pred, target)

        total_loss = (self.l_coord*(xy_loss + wh_loss) + obj_loss + self.l_noobj*(noobj_loss1 + noobj_loss2) + prob_loss)

        return total_loss / batch_size

# %% [markdown]
# ### Step 4. Train the model

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
file_root = '../lab2/all_img/'
train_dataset = YoloDataset(root=file_root, list_file='../lab2/utils/Generate_dataset/voc2007+2012.txt', train=True)
train_loader = DataLoader(train_dataset, batch_size=10, shuffle=True, num_workers=4)

model = YOLO()
state_dict = torch.load('../lab2/pre_train.pt')
model.load_state_dict(state_dict['state_dict'])

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

learning_rate = 1e-4
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)
optimizer.load_state_dict(state_dict['optimizer'])

print('pre_train_complete')
criterion = yoloLoss(l_coord=5,l_noobj=0.5)

best = 1e+30
num_epochs = 15
print("training start!")

for epoch in range(num_epochs):
    model.train()
    total_loss = 0

    for i, (images, target) in enumerate(train_loader):
        images = images.to(device)
        target = target.to(device)

        pred = model(images)
        loss = criterion(pred, target)

        total_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        if (i+1) % 10 == 0:
            print('Epoch [%d/%d], Iter [%d,%d] Loss:%.4f, average_loss: %.4f' % (epoch+1, num_epochs, i+1, len(train_loader), loss.item(), total_loss / (i+1)))
# Out:
# pre_train_complete
# training start!
# Epoch [1/15], Iter [10,430] Loss:291.3601, average_loss: 395.0827
# Epoch [1/15], Iter [20,430] Loss:158.1883, average_loss: 313.6968
# Epoch [1/15], Iter [30,430] Loss:57.4104, average_loss: 236.2149
# Epoch [1/15], Iter [40,430] Loss:28.3829, average_loss: 187.7666
# Epoch [1/15], Iter [50,430] Loss:18.4013, average_loss: 154.9241
# Epoch [1/15], Iter [60,430] Loss:17.3126, average_loss: 131.0629
# Epoch [1/15], Iter [70,430] Loss:6.2994, average_loss: 113.5804
# Epoch [1/15], Iter [80,430] Loss:3.7805, average_loss: 100.2928
# Epoch [1/15], Iter [90,430] Loss:4.0755, average_loss: 89.7543
# Epoch [1/15], Iter [100,430] Loss:3.3359, average_loss: 81.2681
# Epoch [1/15], Iter [110,430] Loss:5.0687, average_loss: 74.3504
# Epoch [1/15], Iter [120,430] Loss:2.6697, average_loss: 68.4626
# Epoch [1/15], Iter [130,430] Loss:3.3146, average_loss: 63.5242
# Epoch [1/15], Iter [140,430] Loss:3.3288, average_loss: 59.2475
# Epoch [1/15], Iter [150,430] Loss:4.8169, average_loss: 55.5845
# Epoch [1/15], Iter [160,430] Loss:3.0858, average_loss: 52.3422
# Epoch [1/15], Iter [170,430] Loss:4.6264, average_loss: 49.4980
# Epoch [1/15], Iter [180,430] Loss:3.4548, average_loss: 46.9678
# Epoch [1/15], Iter [190,430] Loss:4.9870, average_loss: 44.6984
# Epoch [1/15], Iter [200,430] Loss:4.6430, average_loss: 42.6429
# Epoch [1/15], Iter [210,430] Loss:3.3369, average_loss: 40.7866
# Epoch [1/15], Iter [220,430] Loss:3.0324, average_loss: 39.1164
# Epoch [1/15], Iter [230,430] Loss:3.2685, average_loss: 37.5567
# Epoch [1/15], Iter [240,430] Loss:5.8331, average_loss: 36.1603
# Epoch [1/15], Iter [250,430] Loss:4.2954, average_loss: 34.8688
# Epoch [1/15], Iter [260,430] Loss:3.0352, average_loss: 33.6565
# Epoch [1/15], Iter [270,430] Loss:2.2672, average_loss: 32.5426
# Epoch [1/15], Iter [280,430] Loss:5.8128, average_loss: 31.5177
# Epoch [1/15], Iter [290,430] Loss:5.9447, average_loss: 30.5610
# Epoch [1/15], Iter [300,430] Loss:2.9968, average_loss: 29.6574
# Epoch [1/15], Iter [310,430] Loss:3.1547, average_loss: 28.8063
# Epoch [1/15], Iter [320,430] Loss:3.2345, average_loss: 28.0142
# Epoch [1/15], Iter [330,430] Loss:3.3885, average_loss: 27.3036
# Epoch [1/15], Iter [340,430] Loss:4.2719, average_loss: 26.6205
# Epoch [1/15], Iter [350,430] Loss:2.4552, average_loss: 25.9534
# Epoch [1/15], Iter [360,430] Loss:2.8688, average_loss: 25.3402
# Epoch [1/15], Iter [370,430] Loss:2.5063, average_loss: 24.7501
# Epoch [1/15], Iter [380,430] Loss:3.1204, average_loss: 24.1931
# Epoch [1/15], Iter [390,430] Loss:2.0873, average_loss: 23.6561
# Epoch [1/15], Iter [400,430] Loss:2.0052, average_loss: 23.1505
# Epoch [1/15], Iter [410,430] Loss:3.2477, average_loss: 22.6677
# Epoch [1/15], Iter [420,430] Loss:4.1378, average_loss: 22.2175
# Epoch [1/15], Iter [430,430] Loss:3.1197, average_loss: 21.7869
# Epoch [2/15], Iter [10,430] Loss:2.9458, average_loss: 3.2143
# Epoch [2/15], Iter [20,430] Loss:4.2855, average_loss: 3.3781
# Epoch [2/15], Iter [30,430] Loss:3.4743, average_loss: 3.6895
# Epoch [2/15], Iter [40,430] Loss:4.8946, average_loss: 3.6391
# Epoch [2/15], Iter [50,430] Loss:2.6127, average_loss: 3.5039
# Epoch [2/15], Iter [60,430] Loss:4.8538, average_loss: 3.5223
# Epoch [2/15], Iter [70,430] Loss:2.7217, average_loss: 3.5389
# Epoch [2/15], Iter [80,430] Loss:3.1490, average_loss: 3.5672
# Epoch [2/15], Iter [90,430] Loss:5.4548, average_loss: 3.6825
# Epoch [2/15], Iter [100,430] Loss:2.0979, average_loss: 3.6396
# Epoch [2/15], Iter [110,430] Loss:2.5896, average_loss: 3.6028
# Epoch [2/15], Iter [120,430] Loss:2.8761, average_loss: 3.5935
# Epoch [2/15], Iter [130,430] Loss:3.2860, average_loss: 3.6504
# Epoch [2/15], Iter [140,430] Loss:4.2745, average_loss: 3.6611
# Epoch [2/15], Iter [150,430] Loss:2.6868, average_loss: 3.6263
# Epoch [2/15], Iter [160,430] Loss:3.0025, average_loss: 3.6305
# Epoch [2/15], Iter [170,430] Loss:3.4840, average_loss: 3.6327
# Epoch [2/15], Iter [180,430] Loss:2.8179, average_loss: 3.6157
# Epoch [2/15], Iter [190,430] Loss:3.1861, average_loss: 3.6262
# Epoch [2/15], Iter [200,430] Loss:3.3359, average_loss: 3.6298
# Epoch [2/15], Iter [210,430] Loss:2.3460, average_loss: 3.6235
# Epoch [2/15], Iter [220,430] Loss:2.8583, average_loss: 3.6109
# Epoch [2/15], Iter [230,430] Loss:2.3794, average_loss: 3.5919
# Epoch [2/15], Iter [240,430] Loss:3.9593, average_loss: 3.5898
# Epoch [2/15], Iter [250,430] Loss:8.6574, average_loss: 3.6033
# Epoch [2/15], Iter [260,430] Loss:2.7742, average_loss: 3.5944
# Epoch [2/15], Iter [270,430] Loss:4.4897, average_loss: 3.5810
# Epoch [2/15], Iter [280,430] Loss:3.7939, average_loss: 3.5792
# Epoch [2/15], Iter [290,430] Loss:3.1388, average_loss: 3.5905
# Epoch [2/15], Iter [300,430] Loss:3.1602, average_loss: 3.5766
# Epoch [2/15], Iter [310,430] Loss:3.7773, average_loss: 3.5784
# Epoch [2/15], Iter [320,430] Loss:3.2136, average_loss: 3.5798
# Epoch [2/15], Iter [330,430] Loss:2.4660, average_loss: 3.5792
# Epoch [2/15], Iter [340,430] Loss:3.4508, average_loss: 3.5803
# Epoch [2/15], Iter [350,430] Loss:4.5307, average_loss: 3.5844
# Epoch [2/15], Iter [360,430] Loss:2.5460, average_loss: 3.5751
# Epoch [2/15], Iter [370,430] Loss:3.5050, average_loss: 3.5863
# Epoch [2/15], Iter [380,430] Loss:7.0847, average_loss: 3.6040
# Epoch [2/15], Iter [390,430] Loss:2.6038, average_loss: 3.6098
# Epoch [2/15], Iter [400,430] Loss:3.8889, average_loss: 3.6164
# Epoch [2/15], Iter [410,430] Loss:4.2086, average_loss: 3.6220
# Epoch [2/15], Iter [420,430] Loss:2.8291, average_loss: 3.6110
# Epoch [2/15], Iter [430,430] Loss:2.9352, average_loss: 3.6167
# Epoch [3/15], Iter [10,430] Loss:5.3743, average_loss: 3.8910
# Epoch [3/15], Iter [20,430] Loss:4.2854, average_loss: 3.6983
# Epoch [3/15], Iter [30,430] Loss:2.3803, average_loss: 3.7240
# Epoch [3/15], Iter [40,430] Loss:3.6565, average_loss: 3.8132
# Epoch [3/15], Iter [50,430] Loss:4.3133, average_loss: 3.7586
# Epoch [3/15], Iter [60,430] Loss:7.1434, average_loss: 3.8070
# Epoch [3/15], Iter [70,430] Loss:3.6125, average_loss: 3.7525
# Epoch [3/15], Iter [80,430] Loss:4.7429, average_loss: 3.7216
# Epoch [3/15], Iter [90,430] Loss:3.0504, average_loss: 3.7428
# Epoch [3/15], Iter [100,430] Loss:3.4163, average_loss: 3.6951
# Epoch [3/15], Iter [110,430] Loss:2.7023, average_loss: 3.7298
# Epoch [3/15], Iter [120,430] Loss:4.3155, average_loss: 3.6990
# Epoch [3/15], Iter [130,430] Loss:3.3390, average_loss: 3.6804
# Epoch [3/15], Iter [140,430] Loss:2.6821, average_loss: 3.6479
# Epoch [3/15], Iter [150,430] Loss:3.0831, average_loss: 3.6380
# Epoch [3/15], Iter [160,430] Loss:2.9029, average_loss: 3.6811
# Epoch [3/15], Iter [170,430] Loss:2.9268, average_loss: 3.7104
# Epoch [3/15], Iter [180,430] Loss:3.4543, average_loss: 3.7263
# Epoch [3/15], Iter [190,430] Loss:2.9280, average_loss: 3.7230
# Epoch [3/15], Iter [200,430] Loss:3.8868, average_loss: 3.7359
# Epoch [3/15], Iter [210,430] Loss:3.8606, average_loss: 3.7385
# Epoch [3/15], Iter [220,430] Loss:2.8915, average_loss: 3.7288
# Epoch [3/15], Iter [230,430] Loss:2.5891, average_loss: 3.7290
# Epoch [3/15], Iter [240,430] Loss:3.1390, average_loss: 3.7182
# Epoch [3/15], Iter [250,430] Loss:5.3022, average_loss: 3.7093
# Epoch [3/15], Iter [260,430] Loss:5.4725, average_loss: 3.7148
# Epoch [3/15], Iter [270,430] Loss:4.4598, average_loss: 3.7304
# Epoch [3/15], Iter [280,430] Loss:2.6264, average_loss: 3.7134
# Epoch [3/15], Iter [290,430] Loss:4.8117, average_loss: 3.6990
# Epoch [3/15], Iter [300,430] Loss:3.8602, average_loss: 3.6788
# Epoch [3/15], Iter [310,430] Loss:3.6448, average_loss: 3.6817
# Epoch [3/15], Iter [320,430] Loss:5.0470, average_loss: 3.6735
# Epoch [3/15], Iter [330,430] Loss:2.9808, average_loss: 3.6766
# Epoch [3/15], Iter [340,430] Loss:3.7308, average_loss: 3.6757
# Epoch [3/15], Iter [350,430] Loss:2.8575, average_loss: 3.6798
# Epoch [3/15], Iter [360,430] Loss:2.7787, average_loss: 3.6951
# Epoch [3/15], Iter [370,430] Loss:3.0701, average_loss: 3.6984
# Epoch [3/15], Iter [380,430] Loss:3.9523, average_loss: 3.6931
# Epoch [3/15], Iter [390,430] Loss:2.2856, average_loss: 3.6724
# Epoch [3/15], Iter [400,430] Loss:2.4291, average_loss: 3.6642
# Epoch [3/15], Iter [410,430] Loss:3.7106, average_loss: 3.6746
# Epoch [3/15], Iter [420,430] Loss:2.8323, average_loss: 3.6699
# Epoch [3/15], Iter [430,430] Loss:2.9693, average_loss: 3.6640
# Epoch [4/15], Iter [10,430] Loss:3.1550, average_loss: 3.7561
# Epoch [4/15], Iter [20,430] Loss:2.5920, average_loss: 3.6168
# Epoch [4/15], Iter [30,430] Loss:2.9289, average_loss: 3.5218
# Epoch [4/15], Iter [40,430] Loss:4.9623, average_loss: 3.5959
# Epoch [4/15], Iter [50,430] Loss:5.1254, average_loss: 3.6154
# Epoch [4/15], Iter [60,430] Loss:3.1360, average_loss: 3.5234
# Epoch [4/15], Iter [70,430] Loss:3.9617, average_loss: 3.5098
# Epoch [4/15], Iter [80,430] Loss:3.1514, average_loss: 3.4899
# Epoch [4/15], Iter [90,430] Loss:3.1919, average_loss: 3.4965
# Epoch [4/15], Iter [100,430] Loss:3.5221, average_loss: 3.4741
# Epoch [4/15], Iter [110,430] Loss:4.2191, average_loss: 3.5045
# Epoch [4/15], Iter [120,430] Loss:3.3346, average_loss: 3.5399
# Epoch [4/15], Iter [130,430] Loss:4.4818, average_loss: 3.5508
# Epoch [4/15], Iter [140,430] Loss:5.7083, average_loss: 3.6222
# Epoch [4/15], Iter [150,430] Loss:3.9213, average_loss: 3.6580
# Epoch [4/15], Iter [160,430] Loss:4.8492, average_loss: 3.6517
# Epoch [4/15], Iter [170,430] Loss:4.5932, average_loss: 3.6355
# Epoch [4/15], Iter [180,430] Loss:2.3911, average_loss: 3.6315
# Epoch [4/15], Iter [190,430] Loss:3.6764, average_loss: 3.6344
# Epoch [4/15], Iter [200,430] Loss:7.5237, average_loss: 3.6605
# Epoch [4/15], Iter [210,430] Loss:3.8589, average_loss: 3.6414
# Epoch [4/15], Iter [220,430] Loss:3.6358, average_loss: 3.6504
# Epoch [4/15], Iter [230,430] Loss:2.7060, average_loss: 3.6403
# Epoch [4/15], Iter [240,430] Loss:3.1260, average_loss: 3.6332
# Epoch [4/15], Iter [250,430] Loss:2.8654, average_loss: 3.6289
# Epoch [4/15], Iter [260,430] Loss:5.8590, average_loss: 3.6475
# Epoch [4/15], Iter [270,430] Loss:2.0946, average_loss: 3.6600
# Epoch [4/15], Iter [280,430] Loss:4.6700, average_loss: 3.6464
# Epoch [4/15], Iter [290,430] Loss:3.9394, average_loss: 3.6456
# Epoch [4/15], Iter [300,430] Loss:3.0016, average_loss: 3.6413
# Epoch [4/15], Iter [310,430] Loss:2.4111, average_loss: 3.6483
# Epoch [4/15], Iter [320,430] Loss:2.5017, average_loss: 3.6489
# Epoch [4/15], Iter [330,430] Loss:2.8181, average_loss: 3.6475
# Epoch [4/15], Iter [340,430] Loss:4.0015, average_loss: 3.6572
# Epoch [4/15], Iter [350,430] Loss:2.4310, average_loss: 3.6441
# Epoch [4/15], Iter [360,430] Loss:2.7299, average_loss: 3.6349
# Epoch [4/15], Iter [370,430] Loss:2.3720, average_loss: 3.6335
# Epoch [4/15], Iter [380,430] Loss:2.6598, average_loss: 3.6236
# Epoch [4/15], Iter [390,430] Loss:3.1853, average_loss: 3.6107
# Epoch [4/15], Iter [400,430] Loss:3.0720, average_loss: 3.6197
# Epoch [4/15], Iter [410,430] Loss:7.2779, average_loss: 3.6282
# Epoch [4/15], Iter [420,430] Loss:2.2071, average_loss: 3.6201
# Epoch [4/15], Iter [430,430] Loss:3.4511, average_loss: 3.6268
# Epoch [5/15], Iter [10,430] Loss:2.3854, average_loss: 3.7199
# Epoch [5/15], Iter [20,430] Loss:1.8915, average_loss: 3.4340
# Epoch [5/15], Iter [30,430] Loss:2.6180, average_loss: 3.6024
# Epoch [5/15], Iter [40,430] Loss:2.5988, average_loss: 3.5568
# Epoch [5/15], Iter [50,430] Loss:2.6411, average_loss: 3.5341
# Epoch [5/15], Iter [60,430] Loss:4.7783, average_loss: 3.5501
# Epoch [5/15], Iter [70,430] Loss:2.6999, average_loss: 3.4801
# Epoch [5/15], Iter [80,430] Loss:2.3312, average_loss: 3.4304
# Epoch [5/15], Iter [90,430] Loss:6.0403, average_loss: 3.4294
# Epoch [5/15], Iter [100,430] Loss:5.2889, average_loss: 3.4137
# Epoch [5/15], Iter [110,430] Loss:5.0879, average_loss: 3.4461
# Epoch [5/15], Iter [120,430] Loss:3.3495, average_loss: 3.4672
# Epoch [5/15], Iter [130,430] Loss:4.5282, average_loss: 3.4822
# Epoch [5/15], Iter [140,430] Loss:3.4601, average_loss: 3.4813
# Epoch [5/15], Iter [150,430] Loss:3.6622, average_loss: 3.4763
# Epoch [5/15], Iter [160,430] Loss:3.5486, average_loss: 3.4518
# Epoch [5/15], Iter [170,430] Loss:3.9297, average_loss: 3.4494
# Epoch [5/15], Iter [180,430] Loss:1.6837, average_loss: 3.4530
# Epoch [5/15], Iter [190,430] Loss:3.5483, average_loss: 3.4433
# Epoch [5/15], Iter [200,430] Loss:2.8789, average_loss: 3.4367
# Epoch [5/15], Iter [210,430] Loss:1.9878, average_loss: 3.4398
# Epoch [5/15], Iter [220,430] Loss:2.6105, average_loss: 3.4515
# Epoch [5/15], Iter [230,430] Loss:3.0382, average_loss: 3.4426
# Epoch [5/15], Iter [240,430] Loss:8.2029, average_loss: 3.4576
# Epoch [5/15], Iter [250,430] Loss:2.4396, average_loss: 3.4505
# Epoch [5/15], Iter [260,430] Loss:5.0474, average_loss: 3.4793
# Epoch [5/15], Iter [270,430] Loss:4.4585, average_loss: 3.4673
# Epoch [5/15], Iter [280,430] Loss:5.5813, average_loss: 3.4816
# Epoch [5/15], Iter [290,430] Loss:4.2183, average_loss: 3.4834
# Epoch [5/15], Iter [300,430] Loss:2.4461, average_loss: 3.4635
# Epoch [5/15], Iter [310,430] Loss:3.5511, average_loss: 3.4601
# Epoch [5/15], Iter [320,430] Loss:2.3096, average_loss: 3.4451
# Epoch [5/15], Iter [330,430] Loss:3.2340, average_loss: 3.4397
# Epoch [5/15], Iter [340,430] Loss:3.1083, average_loss: 3.4433
# Epoch [5/15], Iter [350,430] Loss:3.2068, average_loss: 3.4494
# Epoch [5/15], Iter [360,430] Loss:4.0058, average_loss: 3.4525
# Epoch [5/15], Iter [370,430] Loss:4.3595, average_loss: 3.4888
# Epoch [5/15], Iter [380,430] Loss:2.8054, average_loss: 3.4804
# Epoch [5/15], Iter [390,430] Loss:3.4519, average_loss: 3.4864
# Epoch [5/15], Iter [400,430] Loss:4.0373, average_loss: 3.4810
# Epoch [5/15], Iter [410,430] Loss:2.2076, average_loss: 3.4838
# Epoch [5/15], Iter [420,430] Loss:4.5443, average_loss: 3.4943
# Epoch [5/15], Iter [430,430] Loss:4.3091, average_loss: 3.4970
# Epoch [6/15], Iter [10,430] Loss:2.7135, average_loss: 3.0622
# Epoch [6/15], Iter [20,430] Loss:2.1896, average_loss: 3.3725
# Epoch [6/15], Iter [30,430] Loss:2.4821, average_loss: 3.3291
# Epoch [6/15], Iter [40,430] Loss:2.6001, average_loss: 3.4034
# Epoch [6/15], Iter [50,430] Loss:2.3811, average_loss: 3.4526
# Epoch [6/15], Iter [60,430] Loss:2.9562, average_loss: 3.5165
# Epoch [6/15], Iter [70,430] Loss:2.2502, average_loss: 3.4644
# Epoch [6/15], Iter [80,430] Loss:3.4743, average_loss: 3.4030
# Epoch [6/15], Iter [90,430] Loss:2.6611, average_loss: 3.4687
# Epoch [6/15], Iter [100,430] Loss:1.7878, average_loss: 3.4187
# Epoch [6/15], Iter [110,430] Loss:2.2465, average_loss: 3.4261
# Epoch [6/15], Iter [120,430] Loss:3.0240, average_loss: 3.4073
# Epoch [6/15], Iter [130,430] Loss:2.6827, average_loss: 3.4120
# Epoch [6/15], Iter [140,430] Loss:2.6439, average_loss: 3.3898
# Epoch [6/15], Iter [150,430] Loss:4.3193, average_loss: 3.4075
# Epoch [6/15], Iter [160,430] Loss:5.1094, average_loss: 3.3914
# Epoch [6/15], Iter [170,430] Loss:2.3883, average_loss: 3.3931
# Epoch [6/15], Iter [180,430] Loss:3.4756, average_loss: 3.3938
# Epoch [6/15], Iter [190,430] Loss:3.2080, average_loss: 3.4209
# Epoch [6/15], Iter [200,430] Loss:3.5495, average_loss: 3.4173
# Epoch [6/15], Iter [210,430] Loss:3.9780, average_loss: 3.4072
# Epoch [6/15], Iter [220,430] Loss:2.6096, average_loss: 3.4057
# Epoch [6/15], Iter [230,430] Loss:4.0429, average_loss: 3.4278
# Epoch [6/15], Iter [240,430] Loss:5.8346, average_loss: 3.4209
# Epoch [6/15], Iter [250,430] Loss:3.4130, average_loss: 3.4188
# Epoch [6/15], Iter [260,430] Loss:2.5963, average_loss: 3.4154
# Epoch [6/15], Iter [270,430] Loss:3.5314, average_loss: 3.4258
# Epoch [6/15], Iter [280,430] Loss:3.2822, average_loss: 3.4131
# Epoch [6/15], Iter [290,430] Loss:6.9567, average_loss: 3.4154
# Epoch [6/15], Iter [300,430] Loss:2.9980, average_loss: 3.4089
# Epoch [6/15], Iter [310,430] Loss:2.8440, average_loss: 3.4294
# Epoch [6/15], Iter [320,430] Loss:3.0302, average_loss: 3.4305
# Epoch [6/15], Iter [330,430] Loss:1.8365, average_loss: 3.4269
# Epoch [6/15], Iter [340,430] Loss:2.9673, average_loss: 3.4217
# Epoch [6/15], Iter [350,430] Loss:4.5053, average_loss: 3.4195
# Epoch [6/15], Iter [360,430] Loss:3.8197, average_loss: 3.4199
# Epoch [6/15], Iter [370,430] Loss:3.0094, average_loss: 3.4135
# Epoch [6/15], Iter [380,430] Loss:2.9890, average_loss: 3.4124
# Epoch [6/15], Iter [390,430] Loss:4.4559, average_loss: 3.4378
# Epoch [6/15], Iter [400,430] Loss:2.9563, average_loss: 3.4343
# Epoch [6/15], Iter [410,430] Loss:3.5580, average_loss: 3.4355
# Epoch [6/15], Iter [420,430] Loss:3.0727, average_loss: 3.4318
# Epoch [6/15], Iter [430,430] Loss:1.9582, average_loss: 3.4307
# Epoch [7/15], Iter [10,430] Loss:8.7572, average_loss: 4.0441
# Epoch [7/15], Iter [20,430] Loss:1.7684, average_loss: 3.5474
# Epoch [7/15], Iter [30,430] Loss:4.8193, average_loss: 3.5171
# Epoch [7/15], Iter [40,430] Loss:2.7792, average_loss: 3.3906
# Epoch [7/15], Iter [50,430] Loss:3.4807, average_loss: 3.3828
# Epoch [7/15], Iter [60,430] Loss:4.2030, average_loss: 3.3896
# Epoch [7/15], Iter [70,430] Loss:2.7464, average_loss: 3.3542
# Epoch [7/15], Iter [80,430] Loss:3.4880, average_loss: 3.3951
# Epoch [7/15], Iter [90,430] Loss:4.4519, average_loss: 3.4051
# Epoch [7/15], Iter [100,430] Loss:3.0039, average_loss: 3.3687
# Epoch [7/15], Iter [110,430] Loss:2.4207, average_loss: 3.3844
# Epoch [7/15], Iter [120,430] Loss:2.7816, average_loss: 3.3917
# Epoch [7/15], Iter [130,430] Loss:3.3456, average_loss: 3.3819
# Epoch [7/15], Iter [140,430] Loss:4.0082, average_loss: 3.3872
# Epoch [7/15], Iter [150,430] Loss:4.0786, average_loss: 3.4008
# Epoch [7/15], Iter [160,430] Loss:4.5699, average_loss: 3.4104
# Epoch [7/15], Iter [170,430] Loss:2.1005, average_loss: 3.4039
# Epoch [7/15], Iter [180,430] Loss:2.2271, average_loss: 3.3883
# Epoch [7/15], Iter [190,430] Loss:3.3218, average_loss: 3.3879
# Epoch [7/15], Iter [200,430] Loss:3.8858, average_loss: 3.3974
# Epoch [7/15], Iter [210,430] Loss:2.8792, average_loss: 3.4341
# Epoch [7/15], Iter [220,430] Loss:2.6627, average_loss: 3.4034
# Epoch [7/15], Iter [230,430] Loss:2.8382, average_loss: 3.3906
# Epoch [7/15], Iter [240,430] Loss:5.0157, average_loss: 3.4205
# Epoch [7/15], Iter [250,430] Loss:5.8356, average_loss: 3.4221
# Epoch [7/15], Iter [260,430] Loss:2.3989, average_loss: 3.4243
# Epoch [7/15], Iter [270,430] Loss:3.5398, average_loss: 3.4082
# Epoch [7/15], Iter [280,430] Loss:3.3909, average_loss: 3.4183
# Epoch [7/15], Iter [290,430] Loss:2.8708, average_loss: 3.4208
# Epoch [7/15], Iter [300,430] Loss:2.1547, average_loss: 3.4238
# Epoch [7/15], Iter [310,430] Loss:2.3423, average_loss: 3.4339
# Epoch [7/15], Iter [320,430] Loss:2.4488, average_loss: 3.4174
# Epoch [7/15], Iter [330,430] Loss:3.9889, average_loss: 3.4177
# Epoch [7/15], Iter [340,430] Loss:3.2546, average_loss: 3.4052
# Epoch [7/15], Iter [350,430] Loss:3.1533, average_loss: 3.4218
# Epoch [7/15], Iter [360,430] Loss:3.1479, average_loss: 3.4219
# Epoch [7/15], Iter [370,430] Loss:3.1104, average_loss: 3.4089
# Epoch [7/15], Iter [380,430] Loss:2.2824, average_loss: 3.4138
# Epoch [7/15], Iter [390,430] Loss:3.6590, average_loss: 3.4193
# Epoch [7/15], Iter [400,430] Loss:3.5866, average_loss: 3.4256
# Epoch [7/15], Iter [410,430] Loss:3.3245, average_loss: 3.4260
# Epoch [7/15], Iter [420,430] Loss:2.4082, average_loss: 3.4251
# Epoch [7/15], Iter [430,430] Loss:5.0369, average_loss: 3.4217
# Epoch [8/15], Iter [10,430] Loss:4.5785, average_loss: 3.1406
# Epoch [8/15], Iter [20,430] Loss:4.5395, average_loss: 3.3108
# Epoch [8/15], Iter [30,430] Loss:2.3932, average_loss: 3.3511
# Epoch [8/15], Iter [40,430] Loss:2.8739, average_loss: 3.3572
# Epoch [8/15], Iter [50,430] Loss:3.1331, average_loss: 3.4169
# Epoch [8/15], Iter [60,430] Loss:2.0433, average_loss: 3.3385
# Epoch [8/15], Iter [70,430] Loss:2.1435, average_loss: 3.2965
# Epoch [8/15], Iter [80,430] Loss:2.8759, average_loss: 3.2845
# Epoch [8/15], Iter [90,430] Loss:2.3188, average_loss: 3.3197
# Epoch [8/15], Iter [100,430] Loss:1.9905, average_loss: 3.2951
# Epoch [8/15], Iter [110,430] Loss:3.5662, average_loss: 3.2946
# Epoch [8/15], Iter [120,430] Loss:2.4176, average_loss: 3.3434
# Epoch [8/15], Iter [130,430] Loss:2.8232, average_loss: 3.3247
# Epoch [8/15], Iter [140,430] Loss:3.9455, average_loss: 3.3311
# Epoch [8/15], Iter [150,430] Loss:3.0210, average_loss: 3.3363
# Epoch [8/15], Iter [160,430] Loss:2.2058, average_loss: 3.3292
# Epoch [8/15], Iter [170,430] Loss:3.2686, average_loss: 3.3492
# Epoch [8/15], Iter [180,430] Loss:2.3994, average_loss: 3.3324
# Epoch [8/15], Iter [190,430] Loss:5.8950, average_loss: 3.3479
# Epoch [8/15], Iter [200,430] Loss:2.8335, average_loss: 3.3354
# Epoch [8/15], Iter [210,430] Loss:3.8580, average_loss: 3.3511
# Epoch [8/15], Iter [220,430] Loss:4.2125, average_loss: 3.3463
# Epoch [8/15], Iter [230,430] Loss:2.9170, average_loss: 3.3389
# Epoch [8/15], Iter [240,430] Loss:9.9030, average_loss: 3.3709
# Epoch [8/15], Iter [250,430] Loss:3.6886, average_loss: 3.3774
# Epoch [8/15], Iter [260,430] Loss:3.0332, average_loss: 3.3773
# Epoch [8/15], Iter [270,430] Loss:3.3413, average_loss: 3.3666
# Epoch [8/15], Iter [280,430] Loss:3.2130, average_loss: 3.3716
# Epoch [8/15], Iter [290,430] Loss:2.9559, average_loss: 3.3723
# Epoch [8/15], Iter [300,430] Loss:3.9328, average_loss: 3.3720
# Epoch [8/15], Iter [310,430] Loss:2.9050, average_loss: 3.3722
# Epoch [8/15], Iter [320,430] Loss:1.6947, average_loss: 3.3759
# Epoch [8/15], Iter [330,430] Loss:5.2750, average_loss: 3.3840
# Epoch [8/15], Iter [340,430] Loss:2.1812, average_loss: 3.3863
# Epoch [8/15], Iter [350,430] Loss:2.1117, average_loss: 3.3869
# Epoch [8/15], Iter [360,430] Loss:2.4075, average_loss: 3.3841
# Epoch [8/15], Iter [370,430] Loss:2.7986, average_loss: 3.3703
# Epoch [8/15], Iter [380,430] Loss:3.7935, average_loss: 3.3536
# Epoch [8/15], Iter [390,430] Loss:4.7637, average_loss: 3.3480
# Epoch [8/15], Iter [400,430] Loss:2.5466, average_loss: 3.3467
# Epoch [8/15], Iter [410,430] Loss:3.4613, average_loss: 3.3383
# Epoch [8/15], Iter [420,430] Loss:3.8434, average_loss: 3.3456
# Epoch [8/15], Iter [430,430] Loss:1.6553, average_loss: 3.3321
# Epoch [9/15], Iter [10,430] Loss:3.1875, average_loss: 3.8832
# Epoch [9/15], Iter [20,430] Loss:3.2121, average_loss: 3.3431
# Epoch [9/15], Iter [30,430] Loss:3.9729, average_loss: 3.4203
# Epoch [9/15], Iter [40,430] Loss:4.8814, average_loss: 3.5429
# Epoch [9/15], Iter [50,430] Loss:3.0712, average_loss: 3.4542
# Epoch [9/15], Iter [60,430] Loss:3.1852, average_loss: 3.3961
# Epoch [9/15], Iter [70,430] Loss:3.6489, average_loss: 3.3755
# Epoch [9/15], Iter [80,430] Loss:3.4545, average_loss: 3.3408
# Epoch [9/15], Iter [90,430] Loss:2.3292, average_loss: 3.3441
# Epoch [9/15], Iter [100,430] Loss:3.5210, average_loss: 3.2880
# Epoch [9/15], Iter [110,430] Loss:4.2942, average_loss: 3.3251
# Epoch [9/15], Iter [120,430] Loss:3.4427, average_loss: 3.3456
# Epoch [9/15], Iter [130,430] Loss:6.6137, average_loss: 3.3587
# Epoch [9/15], Iter [140,430] Loss:3.8495, average_loss: 3.3530
# Epoch [9/15], Iter [150,430] Loss:2.4066, average_loss: 3.3923
# Epoch [9/15], Iter [160,430] Loss:3.9574, average_loss: 3.3768
# Epoch [9/15], Iter [170,430] Loss:4.5017, average_loss: 3.3919
# Epoch [9/15], Iter [180,430] Loss:3.8577, average_loss: 3.3754
# Epoch [9/15], Iter [190,430] Loss:4.5016, average_loss: 3.3788
# Epoch [9/15], Iter [200,430] Loss:3.1046, average_loss: 3.3758
# Epoch [9/15], Iter [210,430] Loss:5.4253, average_loss: 3.3761
# Epoch [9/15], Iter [220,430] Loss:2.3024, average_loss: 3.3653
# Epoch [9/15], Iter [230,430] Loss:4.7046, average_loss: 3.3841
# Epoch [9/15], Iter [240,430] Loss:3.8087, average_loss: 3.3819
# Epoch [9/15], Iter [250,430] Loss:2.4989, average_loss: 3.3751
# Epoch [9/15], Iter [260,430] Loss:2.4847, average_loss: 3.3832
# Epoch [9/15], Iter [270,430] Loss:3.8829, average_loss: 3.3959
# Epoch [9/15], Iter [280,430] Loss:5.0062, average_loss: 3.4072
# Epoch [9/15], Iter [290,430] Loss:2.6797, average_loss: 3.3956
# Epoch [9/15], Iter [300,430] Loss:4.7360, average_loss: 3.3875
# Epoch [9/15], Iter [310,430] Loss:2.0716, average_loss: 3.3956
# Epoch [9/15], Iter [320,430] Loss:2.1386, average_loss: 3.3864
# Epoch [9/15], Iter [330,430] Loss:2.0250, average_loss: 3.3849
# Epoch [9/15], Iter [340,430] Loss:2.6960, average_loss: 3.3685
# Epoch [9/15], Iter [350,430] Loss:2.6504, average_loss: 3.3643
# Epoch [9/15], Iter [360,430] Loss:2.1540, average_loss: 3.3479
# Epoch [9/15], Iter [370,430] Loss:2.3840, average_loss: 3.3319
# Epoch [9/15], Iter [380,430] Loss:2.4725, average_loss: 3.3302
# Epoch [9/15], Iter [390,430] Loss:3.5707, average_loss: 3.3245
# Epoch [9/15], Iter [400,430] Loss:4.5570, average_loss: 3.3272
# Epoch [9/15], Iter [410,430] Loss:2.1455, average_loss: 3.3165
# Epoch [9/15], Iter [420,430] Loss:2.1313, average_loss: 3.3173
# Epoch [9/15], Iter [430,430] Loss:5.1057, average_loss: 3.3137
# Epoch [10/15], Iter [10,430] Loss:2.5443, average_loss: 3.0497
# Epoch [10/15], Iter [20,430] Loss:3.3090, average_loss: 3.1794
# Epoch [10/15], Iter [30,430] Loss:4.0220, average_loss: 3.3386
# Epoch [10/15], Iter [40,430] Loss:2.6100, average_loss: 3.4151
# Epoch [10/15], Iter [50,430] Loss:2.5966, average_loss: 3.2892
# Epoch [10/15], Iter [60,430] Loss:2.5530, average_loss: 3.2758
# Epoch [10/15], Iter [70,430] Loss:2.4952, average_loss: 3.2859
# Epoch [10/15], Iter [80,430] Loss:3.7495, average_loss: 3.2214
# Epoch [10/15], Iter [90,430] Loss:3.6655, average_loss: 3.2582
# Epoch [10/15], Iter [100,430] Loss:3.3421, average_loss: 3.2742
# Epoch [10/15], Iter [110,430] Loss:2.1789, average_loss: 3.2848
# Epoch [10/15], Iter [120,430] Loss:3.6022, average_loss: 3.2907
# Epoch [10/15], Iter [130,430] Loss:4.3842, average_loss: 3.2837
# Epoch [10/15], Iter [140,430] Loss:3.6451, average_loss: 3.2506
# Epoch [10/15], Iter [150,430] Loss:2.3504, average_loss: 3.2629
# Epoch [10/15], Iter [160,430] Loss:3.5660, average_loss: 3.2507
# Epoch [10/15], Iter [170,430] Loss:4.9374, average_loss: 3.2527
# Epoch [10/15], Iter [180,430] Loss:4.1889, average_loss: 3.2485
# Epoch [10/15], Iter [190,430] Loss:3.7096, average_loss: 3.2366
# Epoch [10/15], Iter [200,430] Loss:3.0221, average_loss: 3.2081
# Epoch [10/15], Iter [210,430] Loss:2.4492, average_loss: 3.2013
# Epoch [10/15], Iter [220,430] Loss:2.9393, average_loss: 3.2043
# Epoch [10/15], Iter [230,430] Loss:3.1175, average_loss: 3.2023
# Epoch [10/15], Iter [240,430] Loss:2.5071, average_loss: 3.2189
# Epoch [10/15], Iter [250,430] Loss:2.0680, average_loss: 3.2233
# Epoch [10/15], Iter [260,430] Loss:1.6305, average_loss: 3.2229
# Epoch [10/15], Iter [270,430] Loss:2.5678, average_loss: 3.2291
# Epoch [10/15], Iter [280,430] Loss:3.3332, average_loss: 3.2441
# Epoch [10/15], Iter [290,430] Loss:4.6323, average_loss: 3.2487
# Epoch [10/15], Iter [300,430] Loss:3.3720, average_loss: 3.2701
# Epoch [10/15], Iter [310,430] Loss:4.5063, average_loss: 3.2801
# Epoch [10/15], Iter [320,430] Loss:2.2761, average_loss: 3.2676
# Epoch [10/15], Iter [330,430] Loss:3.1863, average_loss: 3.2671
# Epoch [10/15], Iter [340,430] Loss:1.8506, average_loss: 3.2494
# Epoch [10/15], Iter [350,430] Loss:3.3250, average_loss: 3.2525
# Epoch [10/15], Iter [360,430] Loss:4.0944, average_loss: 3.2566
# Epoch [10/15], Iter [370,430] Loss:4.1247, average_loss: 3.2656
# Epoch [10/15], Iter [380,430] Loss:3.7662, average_loss: 3.2645
# Epoch [10/15], Iter [390,430] Loss:2.5912, average_loss: 3.2749
# Epoch [10/15], Iter [400,430] Loss:2.6595, average_loss: 3.2680
# Epoch [10/15], Iter [410,430] Loss:3.5346, average_loss: 3.2752
# Epoch [10/15], Iter [420,430] Loss:3.9332, average_loss: 3.2682
# Epoch [10/15], Iter [430,430] Loss:2.5057, average_loss: 3.2685
# Epoch [11/15], Iter [10,430] Loss:1.7000, average_loss: 3.4508
# Epoch [11/15], Iter [20,430] Loss:3.5773, average_loss: 3.2744
# Epoch [11/15], Iter [30,430] Loss:1.7244, average_loss: 3.1504
# Epoch [11/15], Iter [40,430] Loss:2.2062, average_loss: 3.1810
# Epoch [11/15], Iter [50,430] Loss:2.4598, average_loss: 3.1665
# Epoch [11/15], Iter [60,430] Loss:4.2998, average_loss: 3.1104
# Epoch [11/15], Iter [70,430] Loss:4.0790, average_loss: 3.1442
# Epoch [11/15], Iter [80,430] Loss:2.8489, average_loss: 3.1250
# Epoch [11/15], Iter [90,430] Loss:2.4847, average_loss: 3.1309
# Epoch [11/15], Iter [100,430] Loss:6.4482, average_loss: 3.2408
# Epoch [11/15], Iter [110,430] Loss:2.5678, average_loss: 3.2088
# Epoch [11/15], Iter [120,430] Loss:3.2613, average_loss: 3.2161
# Epoch [11/15], Iter [130,430] Loss:2.4321, average_loss: 3.2333
# Epoch [11/15], Iter [140,430] Loss:2.0967, average_loss: 3.2414
# Epoch [11/15], Iter [150,430] Loss:4.6851, average_loss: 3.2441
# Epoch [11/15], Iter [160,430] Loss:2.4798, average_loss: 3.2144
# Epoch [11/15], Iter [170,430] Loss:6.0993, average_loss: 3.2322
# Epoch [11/15], Iter [180,430] Loss:4.0272, average_loss: 3.2540
# Epoch [11/15], Iter [190,430] Loss:2.3016, average_loss: 3.2521
# Epoch [11/15], Iter [200,430] Loss:2.4776, average_loss: 3.2502
# Epoch [11/15], Iter [210,430] Loss:2.8798, average_loss: 3.2588
# Epoch [11/15], Iter [220,430] Loss:2.6526, average_loss: 3.2510
# Epoch [11/15], Iter [230,430] Loss:2.4605, average_loss: 3.2450
# Epoch [11/15], Iter [240,430] Loss:3.5128, average_loss: 3.2422
# Epoch [11/15], Iter [250,430] Loss:2.6948, average_loss: 3.2393
# Epoch [11/15], Iter [260,430] Loss:4.3024, average_loss: 3.2596
# Epoch [11/15], Iter [270,430] Loss:3.2902, average_loss: 3.2505
# Epoch [11/15], Iter [280,430] Loss:2.6975, average_loss: 3.2442
# Epoch [11/15], Iter [290,430] Loss:4.0821, average_loss: 3.2404
# Epoch [11/15], Iter [300,430] Loss:4.7431, average_loss: 3.2502
# Epoch [11/15], Iter [310,430] Loss:5.1146, average_loss: 3.2585
# Epoch [11/15], Iter [320,430] Loss:2.7972, average_loss: 3.2662
# Epoch [11/15], Iter [330,430] Loss:2.8764, average_loss: 3.2641
# Epoch [11/15], Iter [340,430] Loss:2.6431, average_loss: 3.2617
# Epoch [11/15], Iter [350,430] Loss:4.2061, average_loss: 3.2579
# Epoch [11/15], Iter [360,430] Loss:2.2748, average_loss: 3.2641
# Epoch [11/15], Iter [370,430] Loss:4.3409, average_loss: 3.2622
# Epoch [11/15], Iter [380,430] Loss:2.6820, average_loss: 3.2485
# Epoch [11/15], Iter [390,430] Loss:2.3614, average_loss: 3.2510
# Epoch [11/15], Iter [400,430] Loss:3.8821, average_loss: 3.2530
# Epoch [11/15], Iter [410,430] Loss:3.8410, average_loss: 3.2544
# Epoch [11/15], Iter [420,430] Loss:2.3857, average_loss: 3.2448
# Epoch [11/15], Iter [430,430] Loss:2.6146, average_loss: 3.2521
# Epoch [12/15], Iter [10,430] Loss:3.1975, average_loss: 3.1531
# Epoch [12/15], Iter [20,430] Loss:2.4572, average_loss: 3.0514
# Epoch [12/15], Iter [30,430] Loss:2.9133, average_loss: 3.0902
# Epoch [12/15], Iter [40,430] Loss:3.1521, average_loss: 3.1006
# Epoch [12/15], Iter [50,430] Loss:2.5212, average_loss: 3.1146
# Epoch [12/15], Iter [60,430] Loss:2.9990, average_loss: 3.0984
# Epoch [12/15], Iter [70,430] Loss:3.7101, average_loss: 3.0762
# Epoch [12/15], Iter [80,430] Loss:2.4855, average_loss: 3.0821
# Epoch [12/15], Iter [90,430] Loss:2.8056, average_loss: 3.1316
# Epoch [12/15], Iter [100,430] Loss:3.1516, average_loss: 3.1718
# Epoch [12/15], Iter [110,430] Loss:2.7663, average_loss: 3.1519
# Epoch [12/15], Iter [120,430] Loss:2.8498, average_loss: 3.2007
# Epoch [12/15], Iter [130,430] Loss:3.8974, average_loss: 3.2059
# Epoch [12/15], Iter [140,430] Loss:2.2706, average_loss: 3.2348
# Epoch [12/15], Iter [150,430] Loss:2.4022, average_loss: 3.2219
# Epoch [12/15], Iter [160,430] Loss:3.7167, average_loss: 3.2294
# Epoch [12/15], Iter [170,430] Loss:2.5387, average_loss: 3.2405
# Epoch [12/15], Iter [180,430] Loss:2.8372, average_loss: 3.2635
# Epoch [12/15], Iter [190,430] Loss:9.2301, average_loss: 3.2909
# Epoch [12/15], Iter [200,430] Loss:2.8692, average_loss: 3.2982
# Epoch [12/15], Iter [210,430] Loss:3.0509, average_loss: 3.3144
# Epoch [12/15], Iter [220,430] Loss:2.9572, average_loss: 3.3139
# Epoch [12/15], Iter [230,430] Loss:1.6078, average_loss: 3.3120
# Epoch [12/15], Iter [240,430] Loss:3.8523, average_loss: 3.3015
# Epoch [12/15], Iter [250,430] Loss:2.9438, average_loss: 3.2963
# Epoch [12/15], Iter [260,430] Loss:4.4171, average_loss: 3.2932
# Epoch [12/15], Iter [270,430] Loss:3.0253, average_loss: 3.2692
# Epoch [12/15], Iter [280,430] Loss:2.2974, average_loss: 3.2634
# Epoch [12/15], Iter [290,430] Loss:3.0432, average_loss: 3.2672
# Epoch [12/15], Iter [300,430] Loss:2.5035, average_loss: 3.2510
# Epoch [12/15], Iter [310,430] Loss:3.1581, average_loss: 3.2412
# Epoch [12/15], Iter [320,430] Loss:3.4411, average_loss: 3.2367
# Epoch [12/15], Iter [330,430] Loss:1.9186, average_loss: 3.2497
# Epoch [12/15], Iter [340,430] Loss:2.6480, average_loss: 3.2456
# Epoch [12/15], Iter [350,430] Loss:3.2907, average_loss: 3.2470
# Epoch [12/15], Iter [360,430] Loss:3.2621, average_loss: 3.2336
# Epoch [12/15], Iter [370,430] Loss:3.7207, average_loss: 3.2471
# Epoch [12/15], Iter [380,430] Loss:4.0276, average_loss: 3.2410
# Epoch [12/15], Iter [390,430] Loss:3.1539, average_loss: 3.2387
# Epoch [12/15], Iter [400,430] Loss:4.7481, average_loss: 3.2394
# Epoch [12/15], Iter [410,430] Loss:4.6060, average_loss: 3.2524
# Epoch [12/15], Iter [420,430] Loss:2.0978, average_loss: 3.2437
# Epoch [12/15], Iter [430,430] Loss:3.9835, average_loss: 3.2445
# Epoch [13/15], Iter [10,430] Loss:4.5527, average_loss: 2.8643
# Epoch [13/15], Iter [20,430] Loss:2.3382, average_loss: 2.8482
# Epoch [13/15], Iter [30,430] Loss:3.6836, average_loss: 3.0491
# Epoch [13/15], Iter [40,430] Loss:3.2001, average_loss: 3.1394
# Epoch [13/15], Iter [50,430] Loss:3.6650, average_loss: 3.0821
# Epoch [13/15], Iter [60,430] Loss:2.7661, average_loss: 3.1194
# Epoch [13/15], Iter [70,430] Loss:2.7119, average_loss: 3.0821
# Epoch [13/15], Iter [80,430] Loss:4.5984, average_loss: 3.0711
# Epoch [13/15], Iter [90,430] Loss:3.2624, average_loss: 3.1047
# Epoch [13/15], Iter [100,430] Loss:5.2146, average_loss: 3.1496
# Epoch [13/15], Iter [110,430] Loss:3.3787, average_loss: 3.1895
# Epoch [13/15], Iter [120,430] Loss:2.4550, average_loss: 3.1973
# Epoch [13/15], Iter [130,430] Loss:2.2342, average_loss: 3.1816
# Epoch [13/15], Iter [140,430] Loss:2.5269, average_loss: 3.1861
# Epoch [13/15], Iter [150,430] Loss:3.4462, average_loss: 3.2202
# Epoch [13/15], Iter [160,430] Loss:2.4893, average_loss: 3.2273
# Epoch [13/15], Iter [170,430] Loss:2.6877, average_loss: 3.2054
# Epoch [13/15], Iter [180,430] Loss:3.6298, average_loss: 3.2003
# Epoch [13/15], Iter [190,430] Loss:4.6288, average_loss: 3.1928
# Epoch [13/15], Iter [200,430] Loss:2.3122, average_loss: 3.1956
# Epoch [13/15], Iter [210,430] Loss:4.1853, average_loss: 3.1967
# Epoch [13/15], Iter [220,430] Loss:2.6996, average_loss: 3.1983
# Epoch [13/15], Iter [230,430] Loss:2.0346, average_loss: 3.2303
# Epoch [13/15], Iter [240,430] Loss:3.5892, average_loss: 3.2361
# Epoch [13/15], Iter [250,430] Loss:2.4001, average_loss: 3.2462
# Epoch [13/15], Iter [260,430] Loss:2.1593, average_loss: 3.2600
# Epoch [13/15], Iter [270,430] Loss:3.3787, average_loss: 3.2518
# Epoch [13/15], Iter [280,430] Loss:2.7858, average_loss: 3.2791
# Epoch [13/15], Iter [290,430] Loss:2.0993, average_loss: 3.2687
# Epoch [13/15], Iter [300,430] Loss:2.6677, average_loss: 3.2746
# Epoch [13/15], Iter [310,430] Loss:4.2336, average_loss: 3.2763
# Epoch [13/15], Iter [320,430] Loss:4.0612, average_loss: 3.2832
# Epoch [13/15], Iter [330,430] Loss:2.4934, average_loss: 3.2753
# Epoch [13/15], Iter [340,430] Loss:2.8494, average_loss: 3.2618
# Epoch [13/15], Iter [350,430] Loss:3.1175, average_loss: 3.2558
# Epoch [13/15], Iter [360,430] Loss:2.6629, average_loss: 3.2608
# Epoch [13/15], Iter [370,430] Loss:2.8003, average_loss: 3.2554
# Epoch [13/15], Iter [380,430] Loss:3.1930, average_loss: 3.2805
# Epoch [13/15], Iter [390,430] Loss:4.2955, average_loss: 3.2858
# Epoch [13/15], Iter [400,430] Loss:2.7874, average_loss: 3.2884
# Epoch [13/15], Iter [410,430] Loss:2.6594, average_loss: 3.2892
# Epoch [13/15], Iter [420,430] Loss:2.3848, average_loss: 3.2984
# Epoch [13/15], Iter [430,430] Loss:1.9445, average_loss: 3.2993
# Epoch [14/15], Iter [10,430] Loss:2.4097, average_loss: 2.9855
# Epoch [14/15], Iter [20,430] Loss:2.4324, average_loss: 3.1095
# Epoch [14/15], Iter [30,430] Loss:4.8890, average_loss: 3.2141
# Epoch [14/15], Iter [40,430] Loss:2.2076, average_loss: 3.0574
# Epoch [14/15], Iter [50,430] Loss:3.6785, average_loss: 3.2183
# Epoch [14/15], Iter [60,430] Loss:2.9967, average_loss: 3.1563
# Epoch [14/15], Iter [70,430] Loss:2.5550, average_loss: 3.1457
# Epoch [14/15], Iter [80,430] Loss:2.1695, average_loss: 3.2191
# Epoch [14/15], Iter [90,430] Loss:2.9344, average_loss: 3.2693
# Epoch [14/15], Iter [100,430] Loss:4.5975, average_loss: 3.2961
# Epoch [14/15], Iter [110,430] Loss:4.4328, average_loss: 3.3257
# Epoch [14/15], Iter [120,430] Loss:4.3095, average_loss: 3.3225
# Epoch [14/15], Iter [130,430] Loss:3.8729, average_loss: 3.3076
# Epoch [14/15], Iter [140,430] Loss:5.1937, average_loss: 3.3457
# Epoch [14/15], Iter [150,430] Loss:2.2282, average_loss: 3.3472
# Epoch [14/15], Iter [160,430] Loss:2.0569, average_loss: 3.3184
# Epoch [14/15], Iter [170,430] Loss:2.0811, average_loss: 3.2828
# Epoch [14/15], Iter [180,430] Loss:2.3021, average_loss: 3.2925
# Epoch [14/15], Iter [190,430] Loss:3.8563, average_loss: 3.3214
# Epoch [14/15], Iter [200,430] Loss:2.9103, average_loss: 3.3289
# Epoch [14/15], Iter [210,430] Loss:2.4659, average_loss: 3.3241
# Epoch [14/15], Iter [220,430] Loss:4.8574, average_loss: 3.3347
# Epoch [14/15], Iter [230,430] Loss:1.9380, average_loss: 3.3384
# Epoch [14/15], Iter [240,430] Loss:3.1708, average_loss: 3.3274
# Epoch [14/15], Iter [250,430] Loss:4.0283, average_loss: 3.3185
# Epoch [14/15], Iter [260,430] Loss:2.9420, average_loss: 3.3229
# Epoch [14/15], Iter [270,430] Loss:2.0704, average_loss: 3.2973
# Epoch [14/15], Iter [280,430] Loss:4.0354, average_loss: 3.3085
# Epoch [14/15], Iter [290,430] Loss:2.6386, average_loss: 3.3212
# Epoch [14/15], Iter [300,430] Loss:2.8362, average_loss: 3.3207
# Epoch [14/15], Iter [310,430] Loss:3.1812, average_loss: 3.3051
# Epoch [14/15], Iter [320,430] Loss:4.0869, average_loss: 3.3011
# Epoch [14/15], Iter [330,430] Loss:5.2077, average_loss: 3.3131
# Epoch [14/15], Iter [340,430] Loss:2.6848, average_loss: 3.3140
# Epoch [14/15], Iter [350,430] Loss:5.2487, average_loss: 3.3218
# Epoch [14/15], Iter [360,430] Loss:2.2177, average_loss: 3.3134
# Epoch [14/15], Iter [370,430] Loss:2.3852, average_loss: 3.2991
# Epoch [14/15], Iter [380,430] Loss:5.0595, average_loss: 3.3131
# Epoch [14/15], Iter [390,430] Loss:1.8502, average_loss: 3.3009
# Epoch [14/15], Iter [400,430] Loss:4.1571, average_loss: 3.3083
# Epoch [14/15], Iter [410,430] Loss:4.9473, average_loss: 3.3090
# Epoch [14/15], Iter [420,430] Loss:3.0264, average_loss: 3.3118
# Epoch [14/15], Iter [430,430] Loss:1.4528, average_loss: 3.2990
# Epoch [15/15], Iter [10,430] Loss:3.4826, average_loss: 3.3914
# Epoch [15/15], Iter [20,430] Loss:3.2410, average_loss: 3.4114
# Epoch [15/15], Iter [30,430] Loss:2.4486, average_loss: 3.4549
# Epoch [15/15], Iter [40,430] Loss:3.5163, average_loss: 3.4190
# Epoch [15/15], Iter [50,430] Loss:3.9044, average_loss: 3.3862
# Epoch [15/15], Iter [60,430] Loss:2.0179, average_loss: 3.3402
# Epoch [15/15], Iter [70,430] Loss:3.0933, average_loss: 3.3160
# Epoch [15/15], Iter [80,430] Loss:3.2941, average_loss: 3.2655
# Epoch [15/15], Iter [90,430] Loss:3.0709, average_loss: 3.3053
# Epoch [15/15], Iter [100,430] Loss:5.7534, average_loss: 3.2983
# Epoch [15/15], Iter [110,430] Loss:3.4021, average_loss: 3.3048
# Epoch [15/15], Iter [120,430] Loss:2.7710, average_loss: 3.2968
# Epoch [15/15], Iter [130,430] Loss:2.5601, average_loss: 3.2726
# Epoch [15/15], Iter [140,430] Loss:3.6639, average_loss: 3.2894
# Epoch [15/15], Iter [150,430] Loss:2.7083, average_loss: 3.2460
# Epoch [15/15], Iter [160,430] Loss:3.5393, average_loss: 3.2587
# Epoch [15/15], Iter [170,430] Loss:3.6922, average_loss: 3.2691
# Epoch [15/15], Iter [180,430] Loss:3.3822, average_loss: 3.2619
# Epoch [15/15], Iter [190,430] Loss:2.8422, average_loss: 3.2583
# Epoch [15/15], Iter [200,430] Loss:2.1148, average_loss: 3.2727
# Epoch [15/15], Iter [210,430] Loss:3.7380, average_loss: 3.2725
# Epoch [15/15], Iter [220,430] Loss:3.0506, average_loss: 3.2645
# Epoch [15/15], Iter [230,430] Loss:3.2979, average_loss: 3.2729
# Epoch [15/15], Iter [240,430] Loss:3.4515, average_loss: 3.2821
# Epoch [15/15], Iter [250,430] Loss:2.4000, average_loss: 3.2769
# Epoch [15/15], Iter [260,430] Loss:3.2532, average_loss: 3.2716
# Epoch [15/15], Iter [270,430] Loss:2.1379, average_loss: 3.2635
# Epoch [15/15], Iter [280,430] Loss:3.3256, average_loss: 3.2503
# Epoch [15/15], Iter [290,430] Loss:5.0381, average_loss: 3.2674
# Epoch [15/15], Iter [300,430] Loss:2.2988, average_loss: 3.2731
# Epoch [15/15], Iter [310,430] Loss:2.0574, average_loss: 3.3160
# Epoch [15/15], Iter [320,430] Loss:3.9700, average_loss: 3.3129
# Epoch [15/15], Iter [330,430] Loss:4.6853, average_loss: 3.3193
# Epoch [15/15], Iter [340,430] Loss:3.6496, average_loss: 3.3155
# Epoch [15/15], Iter [350,430] Loss:3.1122, average_loss: 3.3038
# Epoch [15/15], Iter [360,430] Loss:4.8197, average_loss: 3.3000
# Epoch [15/15], Iter [370,430] Loss:3.3653, average_loss: 3.2865
# Epoch [15/15], Iter [380,430] Loss:2.4008, average_loss: 3.2799
# Epoch [15/15], Iter [390,430] Loss:4.8006, average_loss: 3.3024
# Epoch [15/15], Iter [400,430] Loss:3.8181, average_loss: 3.3000
# Epoch [15/15], Iter [410,430] Loss:3.7619, average_loss: 3.3016
# Epoch [15/15], Iter [420,430] Loss:2.1081, average_loss: 3.3051
# Epoch [15/15], Iter [430,430] Loss:2.8301, average_loss: 3.2934

# %% [markdown]
# ### Step 5. Inference

# %% [markdown]
# ### Step 5-1. Inference (Visualizing)
# - The below code is for visualizing your results.
# - Check out!

# %%
## Visualizing the bouding box image
from lab2.utils.util import *

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')

Color = [[0, 0, 0],
                    [128, 0, 0],
                    [0, 128, 0],
                    [128, 128, 0],
                    [0, 0, 128],
                    [128, 0, 128]]

def visualize(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()

    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0.1)

    for i, box in enumerate(boxes):

        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        result.append([(x1, y1), (x2, y2), SMALL_VOC_CLASSES[cls_index], prob])

    img = np.zeros((h, w, 3), np.uint8)
    img = img + image[:,:,::-1]

    for left_up,right_bottom,class_name,prob in result:
        color = Color[SMALL_VOC_CLASSES.index(class_name)]
        cv2.rectangle(img, left_up, right_bottom, color, 2)
        label = class_name+str(round(prob,2))
        text_size, baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
        p1 = (left_up[0], left_up[1]- text_size[1])
        cv2.rectangle(img, (p1[0] - 2//2, p1[1] - 2 - baseline), (p1[0] + text_size[0], p1[1] + text_size[1]), color, -1)
        cv2.putText(img, label, (p1[0], p1[1] + baseline), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255,255,255), 1, 8)

    plt.imshow(img)

model.eval()
visualize(model, './lab2/utils/Generate_dataset/images/003033.jpg')

# %% [markdown]
# ### Step 6-2. Inference (mAP)
# - The below code is for checkout your network performance,
# - By using this code, your network prediction is saved in Generate_dataset directory
# - Then, %run ./lab2/utils/Generate_dataset/main.py
# - After a few seconds, the mAP is printed.
# - **Note that if your code is correct, the mAP will be over 70.**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')

def write(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()

    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0)

    txt_file = open('../lab2/utils/Generate_dataset/predicted/'+os.path.basename(path)[:-4]+'.txt', 'w')

    for i, box in enumerate(boxes):

        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        txt_file.write(str(SMALL_VOC_CLASSES[cls_index])+' '+'%.6f'%(prob)+' '+str(x1)+' '+str(y1)+' '+str(x2)+' '+str(y2))
        txt_file.write('\n')
    txt_file.close()

import glob

model.eval()
img_names = glob.glob('../lab2/utils/Generate_dataset/images/*')

for i, file_name in enumerate(img_names):
    write(model, file_name)
    if i % 500 == 0:
        print(i)
# Out:
# 0
# 500

# %%
# %run ../lab2/utils/Generate_dataset/main.py
# Out:
# 60.29% = aeroplane AP
# 62.93% = bicycle AP
# 59.26% = bus AP
# 63.71% = car AP
# 72.46% = cat AP
# 72.67% = dog AP
# mAP = 65.22%

# %% [markdown]
# ### *References*
# [1] https://www.pyimagesearch.com/2018/05/14/a-gentle-guide-to-deep-learning-object-detection/
#
# [2] https://github.com/Cartucho/mAP
